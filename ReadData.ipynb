# %% [markdown]
# # サンプルデータの読み込み

# %% [markdown]
# ### ロードボストンデータの読み込み

# %%
# Boston house-price datase for Regression（回帰）
import pandas as pd #データ加工ライブラリpdとして読み込む
from sklearn.datasets import load_boston
from IPython.core.display import display #表の表示機能の読み込み

# %%
# set dataframe
dataset = load_boston()
# 複数次元のデータの場合DataFrame()を使用する
X = pd.DataFrame(dataset.data, columns=dataset.feature_names)
display(X.tail())
# targetをMEDVとして取り出す、1個の場合Series()を使用する
y = pd.Series(dataset.target, name='MEDV')# Median value of owner-occupied homes in $1000's
display(y.tail())
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, dtype: float64

# %%
print('--------------------------------------')
print('X shape:{}'.format(X.shape))# shapeで行列数を取り出せる
print('--------------------------------------')
print(y.describe())# describeで統計値の取り出し
display(X.join(y).head())# きれいに強制出力してくれる
# Out:
# --------------------------------------
# X shape:(506, 13)
# --------------------------------------
# count    506.000000
# mean      22.532806
# std        9.197104
# min        5.000000
# 25%       17.025000
# 50%       21.200000
# 75%       25.000000
# max       50.000000
# Name: MEDV, dtype: float64
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# ### 画像の表示

# %%
from IPython.display import Image
Image(filename='./images/boston_vars.JPG', width=500)

# %% [markdown]
# ### CSVからの読み出し

# %%
# big mart sales amount for Regression
# https://datahack.analyticsvidhya.com/contest/practice-problem-big-mart-sales-iii/
import pandas as pd
import numpy as np

df = pd.read_csv('./data/av_big_mart_sales_UWu5bXk.csv',
                 header=0)  # headerなしの場合はNone
X = df.iloc[:, :-1]  # 全行対象,最終カラム以外をXとする
y = df.iloc[:, -1] # 全行対象,最終カラムをyとする

# check the shape
print('----------------------------------------')
print('X shape: (%i,%i)' %X.shape)
print('----------------------------------------')
print(y.describe())
# 目的変数に欠損が含まれているとアルゴリズムが学習できないためチェック
print('----------------------------------------')
print('Check null count of target variable: %i' %y.isnull().sum())
print('----------------------------------------')
display(X.join(y).head())
# Out:
# ----------------------------------------
# X shape: (8523,11)
# ----------------------------------------
# count     8523.000000
# mean      2181.288914
# std       1706.499616
# min         33.290000
# 25%        834.247400
# 50%       1794.331000
# 75%       3101.296400
# max      13086.964800
# Name: Item_Outlet_Sales, dtype: float64
# ----------------------------------------
# Check null count of target variable: 0
# ----------------------------------------
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# ...

# %%
Image(filename='./images/bigmart_vars.JPG', width=500)

# %% [markdown]
# ### Irisの読み込み

# %%
# Iris dataset for Classification
# Classic and very easy multi-class classification dataset
import pandas as pd
from sklearn.datasets import load_iris

dataset = load_iris()

# Set dataframe
X = pd.DataFrame(dataset.data, columns=dataset.feature_names)
y = pd.Series(dataset.target, name='y')
# check the shape
print('----------------------------------')
print(f'X shape:{X.shape}')
print('----------------------------------')
#value_counts()はカテゴリーの数でまとめてくれる
print(y.value_counts())
display(X.join(y).head())
print(dataset.DESCR)
# Out:
# ----------------------------------
# X shape:(150, 4)
# ----------------------------------
# 2    50
# 1    50
# 0    50
# Name: y, dtype: int64
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  y
# 0                5.1               3.5                1.4               0.2  0
# 1                4.9               3.0                1.4               0.2  0
# 2                4.7               3.2                1.3               0.2  0
# 3                4.6               3.1                1.5               0.2  0
# 4                5.0               3.6                1.4               0.2  0
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
# ...

# %% [markdown]
# ### Breast cancer wisconsin datasetの読み出し

# %%
# Breast cancer wisconsin dataset for Classification
import pandas as pd
from sklearn.datasets import load_breast_cancer
dataset = load_breast_cancer()

#set dataframe
X = pd.DataFrame(dataset.data, columns=dataset.feature_names)
y = pd.Series(dataset.target, name='y')

#check the shape
print('------------------------------------------')
print(f'X shape:{X.shape}')
print('------------------------------------------')
print(y.value_counts())
print('------------------------------------------')
display(X.join(y).head())
# Out:
# ------------------------------------------
# X shape:(569, 30)
# ------------------------------------------
# 1    357
# 0    212
# Name: y, dtype: int64
# ------------------------------------------
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# ...

# %% [markdown]
# ### Loan screening CSVの読み込み

# %%
# Loan screening data for Classification 
import pandas as pd

df = pd.read_csv('./data/av_loan_u6lujuX_CVtuZ9i.csv', header=0)
print(df.iloc[:0,:])
print(df.shape)
X = df.iloc[:,:-1]
print(X.shape)
y = df.iloc[:,-1]
print(y.shape)
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []
# (614, 13)
# (614, 12)
# (614,)

# %%
# check the shape
print('----------------------------------------')
print(f'X shape:{X.shape}')
print('----------------------------------------')
print(y.value_counts())
print('----------------------------------------')
print(f'Check null count:{y.isnull().sum()}')
print('----------------------------------------')
# Out:
# ----------------------------------------
# X shape:(614, 12)
# ----------------------------------------
# Y    422
# N    192
# Name: Loan_Status, dtype: int64
# ----------------------------------------
# Check null count:0
# ----------------------------------------

# %%
# Converting string to number
# 機械学習において文字列は理解できないため数字に変換する
class_mapping = {'N':1, 'Y':0}
print(y.tail())
# Nを1に,Yを0に変えている
y = y.map(class_mapping)
print(y.tail())
# check the converted result
print('check the result converted')
print(y.value_counts())
display(X.join(y).head())# headのdefoultは5
# Out:
# 609    Y
# 610    Y
# 611    Y
# 612    Y
# 613    N
# Name: Loan_Status, dtype: object
# 609    0
# 610    0
# 611    0
# 612    0
# 613    1
# Name: Loan_Status, dtype: int64
# check the result converted
# 0    422
# 1    192
# Name: Loan_Status, dtype: int64
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# ...

# %%
Image(filename='./images/Loan_vars.JPG', width=500)
